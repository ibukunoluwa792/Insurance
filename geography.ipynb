# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
admiral_2 =  pd.read_csv("Geographics.csv")
admiral_2.head()
# Out:
#    ZipCode  ZIP_AverageHomeValue  ZIP_AverageIncome  ZIP_Population  \
# 0    27741                481400             141522           11315
# 1    23482                348700              73113            5142
# 2    15851                238100              62106           37265
# 3    43201                300300              77669           43876
# 4    11505                298700              82283           30590
#
#    ZIP_LandArea
# 0        37.130
# 1        60.237
# 2        20.490
# 3        12.627
# 4        16.281

# %%
len(admiral_2)
# Out:
# 2016

# %%
admiral_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2016 entries, 0 to 2015
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ZipCode               2016 non-null   int64
#  1   ZIP_AverageHomeValue  2016 non-null   int64
#  2   ZIP_AverageIncome     2016 non-null   int64
#  3   ZIP_Population        2016 non-null   int64
#  4   ZIP_LandArea          2016 non-null   float64
# dtypes: float64(1), int64(4)
# memory usage: 78.9 KB

# %%
admiral_2.describe()
# Out:
#             ZipCode  ZIP_AverageHomeValue  ZIP_AverageIncome  ZIP_Population  \
# count   2016.000000          2.016000e+03        2016.000000     2016.000000
# mean   57680.717262          1.652956e+05       56013.540675    15524.653274
# std    27153.683150          1.320633e+05       25925.837984    16259.257728
# min    10001.000000          0.000000e+00           0.000000        0.000000
# 25%    36718.500000          8.747500e+04       40195.250000     2787.000000
# 50%    60041.500000          1.267500e+05       50318.000000     8986.500000
# 75%    80876.250000          1.984250e+05       65719.250000    24637.750000
# max    99999.000000          2.000000e+06      215122.000000   111086.000000
#
#        ZIP_LandArea
# count   2016.000000
# mean      98.156966
# std      174.968244
# min        0.000000
# 25%       12.548500
# 50%       45.362500
# 75%      110.431750
# max     2509.559000

# %%
numerical_columns = admiral_2.select_dtypes(include=['number'])
corr_matrix = numerical_columns.corr()
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap of Numerical Features')
plt.show()
